# %% [markdown]
# - date: 2021-10-01 10:17:17
# - author: Jerry Su
# - slug: Data-EDA
# - title: Data EDA
# - category:
# - tags: NLP

# %%
# !ls ../../../cache
# Out:
# ArticlesGenerator-Readers  train.json  vocab.txt

# %%
import json
import pandas as pd
from collections import OrderedDict
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# ### 1. labels

# %%
labels_file = open('../../../cache/labels.json', 'r', encoding='utf-8')
label_dicts = OrderedDict()
for line in labels_file:
    label = json.loads(line)
    label_dicts[label['label']] = label['label_des']
label_dicts
# Out:
# OrderedDict([('0', '打车'),
#              ('1', '地图导航'),
#              ('2', '免费WIFI'),
#              ('3', '租车'),
#              ('4', '同城服务'),
#              ('5', '快递物流'),
#              ('6', '婚庆'),
#              ('7', '家政'),
#              ('8', '公共交通'),
#              ('9', '政务'),
#              ('10', '社区服务'),
#              ('11', '薅羊毛'),
#              ('12', '魔幻'),
#              ('13', '仙侠'),
#              ('14', '卡牌'),
#              ('15', '飞行空战'),
#              ('16', '射击游戏'),
#              ('17', '休闲益智'),
#              ('18', '动作类'),
#              ('19', '体育竞技'),
#              ('20', '棋牌中心'),
#              ('21', '经营养成'),
#              ('22', '策略'),
#              ('23', 'MOBA'),
#              ('24', '辅助工具'),
#              ('25', '约会社交'),
#              ('26', '即时通讯'),
#              ('27', '工作社交'),
#              ('28', '论坛圈子'),
#              ('29', '婚恋社交'),
#              ('30', '情侣社交'),
#              ('31', '社交工具'),
#              ('32', '生活社交'),
#              ('33', '微博博客'),
#              ('34', '新闻'),
#              ('35', '漫画'),
#              ('36', '小说'),
#              ('37', '技术'),
#              ('38', '教辅'),
#              ('39', '问答交流'),
#              ('40', '搞笑'),
#              ('41', '杂志'),
#              ('42', '百科'),
#              ('43', '影视娱乐'),
#              ('44', '求职'),
#              ('45', '兼职'),
#              ('46', '视频'),
#              ('47', '短视频'),
#              ('48', '音乐'),
#              ('49', '直播'),
#              ('50', '电台'),
#              ('51', 'K歌'),
#              ('52', '成人'),
#              ('53', '中小学'),
#              ('54', '职考'),
#              ('55', '公务员'),
#              ('56', '英语'),
#              ('57', '视频教育'),
#              ('58', '高等教育'),
#              ('59', '成人教育'),
#              ('60', '艺术'),
#              ('61', '语言(非英语)'),
#              ('62', '旅游资讯'),
#              ('63', '综合预定'),
#              ('64', '民航'),
#              ('65', '铁路'),
#              ('66', '酒店'),
#              ('67', '行程管理'),
#              ('68', '民宿短租'),
#              ('69', '出国'),
#              ('70', '工具'),
#              ('71', '亲子儿童'),
#              ('72', '母婴'),
#              ('73', '驾校'),
#              ('74', '违章'),
#              ('75', '汽车咨询'),
#              ('76', '汽车交易'),
#              ('77', '日常养车'),
#              ('78', '行车辅助'),
#              ('79', '租房'),
#              ('80', '买房'),
#              ('81', '装修家居'),
#              ('82', '电子产品'),
#              ('83', '问诊挂号'),
#              ('84', '养生保健'),
#              ('85', '医疗服务'),
#              ('86', '减肥瘦身'),
#              ('87', '美妆美业'),
#              ('88', '菜谱'),
#              ('89', '餐饮店'),
#              ('90', '体育咨讯'),
#              ('91', '运动健身'),
#              ('92', '支付'),
#              ('93', '保险'),
#              ('94', '股票'),
#              ('95', '借贷'),
#              ('96', '理财'),
#              ('97', '彩票'),
#              ('98', '记账'),
#              ('99', '银行'),
#              ('100', '美颜'),
#              ('101', '影像剪辑'),
#              ('102', '摄影修图'),
#              ('103', '相机'),
#              ('104', '绘画'),
#              ('105', '二手'),
#              ('106', '电商'),
#              ('107', '团购'),
#              ('108', '外卖'),
#              ('109', '电影票务'),
#              ('110', '社区超市'),
#              ('111', '购物咨询'),
#              ('112', '笔记'),
#              ('113', '办公'),
#              ('114', '日程管理'),
#              ('115', '女性'),
#              ('116', '经营'),
#              ('117', '收款'),
#              ('118', '其他')])

# %% [markdown]
# ### 2. train dataset

# %%
train_file = open('../../../cache/train.json', 'r', encoding='utf-8')
instances = []
for line in train_file:
    instance = json.loads(line)
    instances.append([instance['label'], instance['label_des'], instance['sentence']])
print(f'Train Dataset size: {len(instances)}')
print(f'Sample: {instances[0]}')
# Out:
# Train Dataset size: 12133
# Sample: ['11', '薅羊毛', '活动新用户领5元现金即日起成功注册酷划的新用户，填写邀请码80008即可领取5元现金奖励哦。小伙伴们不要错过，赶快来酷划锁屏领红包吧~每天解锁50次，一年可赚上千元酷划锁屏是一款可以自动赚钱的手机锁屏APP，每次解锁手机均有数额不等的现金奖励。赚到的钱可以极速提现到微信钱包、支付宝，也可以用来购买爆款商品。除手机解锁可以赚钱外，酷划还提供邀请赚、分享赚、高额赚等十余种赚钱方式，零成本可得高额回报。三年时间里，酷划已累计服务了超一亿名用户。在手赚软件中处于无可争议的领先地位。手机赚钱，用酷划锁屏就对了功能介绍手机解锁领现金每次解锁均有现金奖励锁屏精选新鲜资讯，边看边赚零花钱十种以上赚钱方式邀请赚、分享赚、试玩赚…多种赚钱方式任你选每天花上五分钟，酷划收入翻倍领邀请徒弟收入加倍邀请好友体验酷划，建立师徒关系徒弟挣钱，师傅得现金奖励提现购物任你挑选您的收入可提现，购物，话费充值微信一元提现，极速到账官网www.coohua.com微信公众号酷划在线客服邮箱help@coohua.com,每天解锁50次，一年可赚上千块,1、客户端个人中心电商相关功能下线2、锁屏改造客户端SDK']

# %%
train_df = pd.DataFrame(instances, columns=['label', 'label_des', 'sentence'])
train_df
# Out:
#       label label_des                                           sentence
# 0        11       薅羊毛  活动新用户领5元现金即日起成功注册酷划的新用户，填写邀请码80008即可领取5元现金奖励哦。...
# 1        95        借贷  产品简介小腰包APP是友戏互联为年轻白领人群打造的一款互联网消费金融应用，以用户日常消费行为...
# 2        74        违章  6000万车主都在用的查违章洗车养车加油车险优惠一站式用车服务平台，河南交警系统直连特色功能...
# 3        70        工具  这不仅是一个一站式的服务平台，在使用魅族手机过程中遇到什么可以通过这个应用来寻求解决，还是您...
# 4        58      高等教育  "2019普通话学习、教师、公务员、播音主持、学拼音、配音员做普通话水平测试的优选软件1.普...
# ...     ...       ...                                                ...
# 12128    70        工具  应用简介「查找手机」是魅族手机内置防盗服务的同名独立应用，目前已支持主流安卓机型。当手机不慎...
# 12129    24      辅助工具  手游充值4折起，自动折扣，无需代充，终生折扣。小7手游，直接的手游福利1、手游充值4折千款热...
# 12130    63      综合预定  去哪儿旅行总有你要的低价作为中国的较早无线和在线旅游平台，去哪儿旅行支持用户低价购买近60万...
# 12131    92        支付  随行付MPOS正式更名为随行付Plus，信用卡生活从此开始，崭新面貌，更多功能等你体验。随行...
# 12132    34        新闻                                   掌上阅读用掌薪，个性化阅读APP
#
# [12133 rows x 3 columns]

# %%
print('label frequency')
train_df_vcs = train_df['label_des'].value_counts()
for name, value in zip(train_df_vcs.index, train_df_vcs):
    print(f'{name}\t: {value}')
# Out:
# label frequency
# 工具	: 1980
# 休闲益智	: 952
# 亲子儿童	: 506
# 借贷	: 375
# 中小学	: 369
# 动作类	: 364
# 经营养成	: 280
# 棋牌中心	: 264
# 电商	: 263
# 小说	: 253
# 新闻	: 240
# 视频	: 237
# 理财	: 210
# 论坛圈子	: 204
# 射击游戏	: 180
# 策略	: 173
# 体育竞技	: 169
# 辅助工具	: 163
# 购物咨询	: 156
# 英语	: 149
# 音乐	: 143
# 仙侠	: 142
# 直播	: 138
# 约会社交	: 135
# 办公	: 135
# 同城服务	: 129
# 公共交通	: 125
# 职考	: 121
# 银行	: 116
# 彩票	: 115
# 经营	: 114
# 摄影修图	: 112
# 其他	: 111
# 政务	: 111
# 股票	: 108
# 魔幻	: 102
# 运动健身	: 99
# 电子产品	: 86
# 医疗服务	: 84
# 成人教育	: 82
# 薅羊毛	: 76
# 社区服务	: 74
# 相机	: 71
# 影像剪辑	: 69
# 即时通讯	: 58
# 高等教育	: 58
# 支付	: 54
# 卡牌	: 53
# 行车辅助	: 52
# 短视频	: 46
# 兼职	: 46
# 菜谱	: 44
# 求职	: 44
# 快递物流	: 44
# 社交工具	: 43
# 养生保健	: 43
# 漫画	: 42
# 驾校	: 42
# 旅游资讯	: 42
# 艺术	: 40
# 教辅	: 40
# 体育咨讯	: 39
# 地图导航	: 37
# 记账	: 37
# 日常养车	: 36
# 问诊挂号	: 36
# 汽车咨询	: 35
# 母婴	: 34
# 免费WIFI	: 33
# 女性	: 32
# 绘画	: 31
# 汽车交易	: 31
# 电台	: 30
# 飞行空战	: 30
# 语言(非英语)	: 29
# 买房	: 28
# 美颜	: 28
# 社区超市	: 27
# 笔记	: 27
# 婚恋社交	: 27
# 综合预定	: 26
# 装修家居	: 26
# 保险	: 26
# MOBA	: 25
# 民航	: 24
# 二手	: 24
# 租房	: 23
# 收款	: 23
# 美妆美业	: 23
# 工作社交	: 22
# 违章	: 22
# 团购	: 22
# 技术	: 21
# 杂志	: 21
# 租车	: 20
# 搞笑	: 20
# 电影票务	: 20
# 打车	: 20
# 铁路	: 19
# 微博博客	: 18
# 问答交流	: 17
# 生活社交	: 17
# 视频教育	: 16
# 百科	: 15
# K歌	: 15
# 公务员	: 14
# 家政	: 14
# 影视娱乐	: 13
# 日程管理	: 13
# 酒店	: 11
# 情侣社交	: 11
# 成人	: 11
# 外卖	: 10
# 减肥瘦身	: 9
# 行程管理	: 7
# 餐饮店	: 5
# 婚庆	: 3
# 出国	: 3
# 民宿短租	: 1

# %%
train_df[train_df['sentence'].str.len() < 13]
# Out:
#       label label_des      sentence
# 18       18       动作类   国产轻巧的桌面BUG。
# 155      71      亲子儿童  小宝贝们，来做小小店长吧
# 350      70        工具   版本4.3.8.1了。
# 975      31      社交工具   专业安全的微信定位助手
# 1012     20      棋牌中心   版本2.1.9和错误。
# 1111     71      亲子儿童  儿童看图识字介绍儿童看图
# 1150     17      休闲益智  锻炼大脑，提高幽默感了。
# 1937     70        工具  遥控助手，智能电视遥控器
# 2347     36        小说   快来挑选你喜欢的小说吧
# 2647     18       动作类   畅快pk，还原传奇盛况
# 2772     56        英语   一款小学英语的学习软件
# 2792     34        新闻   捕捉热点，收获快乐，。
# 2930     28      论坛圈子   空间攒人气，空间魅力值
# 3171     70        工具  随意双开，生活工作两不误
# 4158     91      运动健身  "有趣的路书社交玩法1.
# 4426      1      地图导航    官方介绍天翼导航产品
# 4780     70        工具    懂你的文字输入法了。
# 4928     86      减肥瘦身    瑜伽小课堂开始了，。
# 5080     17      休闲益智    用你的领导力压倒对手
# 5186     70        工具  一款可以互动分享的阅读器
# 5371    118        其他  软件介绍杏仁儿是一款专门
# 5735    116        经营    秒速找货，上叭叭速配
# 5814     70        工具    史诗战役由你量身打造
# 6103     49        直播   全民原创互动的体育直播
# 6317     88        菜谱   美好生活，从学做菜开始
# 6415     71      亲子儿童  安抚宝宝就陪Ta看动画片
# 6968     19      体育竞技  都市战场掀起真实射击狂潮
# 7824    103        相机  最有名最棒的镜像效果应用
# 7988     17      休闲益智    全新情节找茬神作，。
# 8211     17      休闲益智    雪地大乱斗，胜者吃鸡
# 8467     16      射击游戏    跟水果来一场雪球大战
# 8501     20      棋牌中心  公平斗地主，输赢全靠牌技
# 8674     21      经营养成   全真人美女帅哥聊天互动
# 8743     70        工具   着名景点全景图片逼真看
# 8849     18       动作类   一场趣味十足的酷跑之旅
# 9118     16      射击游戏   令人欲罢不能的飞刀挑战
# 9756     70        工具    您的随身监控设备，。
# 9807     36        小说  追更，各类小说，一键阅读
# 9967     46        视频  支持各类格式本地视频播放
# 10138    15      飞行空战  简单耐玩的迷你小飞机游戏
# 10230    28      论坛圈子  许嵩粉丝交流平台，部分。
# 11007    18       动作类   骑上帅气坐骑开始飞驰吧
# 11079    70        工具  版本1.8了一些BUG。
# 11769    70        工具    懂你的文字输入法了。
