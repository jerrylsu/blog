# %% [markdown]
# - title: My notebook
# - author: John Doe
# - date: 2018-05-11
# - category: pyhton
# - tags: pip

# %%
bsasa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2f3b0a4dec2c> in <module>
# ----> 1 bsasa
#
# NameError: name 'bsasa' is not defined
